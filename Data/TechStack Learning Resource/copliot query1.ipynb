# %%
from seleniumbase import Driver
from seleniumbase import page_actions
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
import os
import requests
import time
import csv
import pandas as pd
import multiprocessing 
import threading
import random
import concurrent.futures

# %%
class Copliot:
    def __init__(self):
        self.driver = Driver(uc=True)
        self.query_dict_list = {}
        self.queue = []
        self.start =0
        self.end = 0
        self.InitQueryList()

    def InitQueryList(self):   
        df = pd.read_csv("skills.csv", usecols=['Search Keyword', 'Resource Path'])
        for index, row in df.iterrows():
            key =  str(row['Search Keyword'])
            value = str(row['Resource Path'])
            if key is not self.query_dict_list:
                self.query_dict_list[key]= value
                self.queue.append(key)
        df = pd.read_csv("groups.csv", usecols=['Search Keyword', 'Resource Path'])
        for index, row in df.iterrows():
            key =  str(row['Search Keyword'])
            value = str(row['Resource Path'])
            if key is not self.query_dict_list:
                self.query_dict_list[key]= value
                self.queue.append(key) 
        self.end =len(self.queue)
        print(self.end)
        
    def Login(self,id,pw):
        url = "https://login.live.com/"
        try:
            t = random.uniform(0.0, 2.0)
            print(t,"\n")
            time.sleep(t)
            self.driver.get(url)
            #time.sleep(3)
            #id_field = self.driver.find_element(by=By.XPATH, value="(//input[@id='i0116'])[1]")
            #id_field.send_keys(id)
            #WebDriverWait(self.driver, 1).until(EC.element_to_be_clickable((By.XPATH, "(//button[normalize-space()='Next'])[1]"))).click()
            #time.sleep(2)
            #pw_field = self.driver.find_element(by=By.XPATH, value="(//input[@id='i0118'])[1]")
            #pw_field.send_keys(pw)
            #WebDriverWait(self.driver, 1).until(EC.element_to_be_clickable((By.XPATH, "(//button[normalize-space()='Sign in'])[1]"))).click()
            #time.sleep(2)
        except:
            return False

        return True
        
    def GoToCopliot(self):
        url = "https://www.bing.com/search?q=Bing%20AI&showconv=1&form=MG0AUO"
        # go 3 time to bypass the popup
        self.driver.get(url)
        time.sleep(2)
        self.driver.get(url)
        time.sleep(2)
        return True

    def QueryCopliot(self):
        if self.start < self.end:
            keyword = self.queue[self.start]
            path = self.query_dict_list.get(keyword)
            url = "https://www.bing.com/search?q=Bing%20AI&showconv=1&form=MG0AUO"
            query = "what is "+ keyword +" in one sentence and give me 5 reference links which I can learn for free." 
            dir = path.rsplit("/")[0]
            if not os.path.exists(dir):
                os.makedirs(dir)
            with open(path, 'w', encoding='utf-8') as file:
                self.driver.get(url)
                time.sleep(5)
                dom1 = self.driver.find_element(by=By.CSS_SELECTOR, value=".cib-serp-main").shadow_root
                input_shadow_dom2 = dom1.find_element(by=By.CSS_SELECTOR, value="#cib-action-bar-main").shadow_root
                input_shadow_dom3 = input_shadow_dom2.find_element(by=By.CSS_SELECTOR, value="cib-text-input[serp-slot='none']").shadow_root
                text_field = input_shadow_dom3.find_element(by=By.CSS_SELECTOR, value="#searchbox")
                text_field.send_keys(query)
                time.sleep(1)
                input_shadow_dom2.find_element(by=By.CSS_SELECTOR, value="button[aria-label='Submit']").click()
                time.sleep(30)
                response_shadow_dom2 = dom1.find_element(by=By.CSS_SELECTOR, value="#cib-conversation-main").shadow_root
                response_shadow_dom3 = response_shadow_dom2.find_element(by=By.CSS_SELECTOR, value="cib-chat-turn[serp-slot='none']").shadow_root
                response_shadow_dom4 = response_shadow_dom3.find_element(by=By.CSS_SELECTOR, value=".response-message-group").shadow_root
                response_shadow_dom5 = response_shadow_dom4.find_element(by=By.CSS_SELECTOR, value="cib-message:nth-child(2)").shadow_root
                response = response_shadow_dom5.find_element(by=By.CSS_SELECTOR, value="div[class='content']")
                content = response.get_attribute("innerHTML")
                file.write(content)  
                file.close()
                print(self.start,keyword,"\n")
            file.close()
            self.start += 1
            self.QueryCopliot()
              

    def CloseDriver(self):
        print("run")
        self.driver.Quit()

# %%
test = Copliot()
# Out:
# 1504

# %%
test.start = 872
test.end = 1050

# %%
test.QueryCopliot()
# Out:
# 872 cognito in tech
#
# 873 maximo in tech
#
# 874 azkaban in tech
#
# 875 eslint in tech
#
# 876 jest in tech
#
# 877 salt in tech
#
# 878 storybook in tech
#
# 879 openvz in tech
#
# 880 birt report in tech
#
# 881 aws cdk in tech
#
# 882 nose in tech
#
# 883 fluentd in tech
#
# 884 axios in tech
#
# 885 dataiku in tech
#
# 886 eks in tech
#
# 887 strata in tech
#
# 888 es5 in tech
#
# 889 liquibase in tech
#
# 890 pullreview in tech
#
# 891 sr sam 34 35 in tech
#
# 892 konga in tech
#
# 893 aerospike in tech
#
# 894 titan in tech
#
# 895 shell script in tech
#
# 896 jaeger in tech
#
# 897 experian in tech
#
# 898 packer in tech
#
# 899 meteor in tech
#
# 900 liferay in tech
#
# 901 visual studio in tech
#
# 902 crashlytics in tech
#
# 903 jmp in tech
#
# 904 openid in tech
#
# 905 netegrity in tech
#
# 906 data extraction in tech
#
# 907 kinesis in tech
#
# 908 dojo in tech
#
# 909 testrail in tech
#
# 910 swagger in tech
#
# 911 sentry in tech
#
# 912 tcp in tech
#
# 913 xen in tech
#
# 914 weblogic in tech
#
# 915 dubbo in tech
#
# 916 camunda in tech
#
# 917 cakephp in tech
#
# 918 sockets in tech
#
# 919 composer in tech
#
# 920 combine in tech
#
# 921 rnn in tech
#
# 922 jms in tech
#
# 923 ie10+ in tech
#
# 924 parcel in tech
#
# 925 iis in tech
#
# 926 xray in tech
#
# 927 buildkite in tech
#
# 928 gemfire in tech
#
# 929 core data in tech
#
# 930 argocd in tech
#
# 931 sonar qube in tech
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 test.QueryCopliot()
#
# Cell In[2], line 89, in Copliot.QueryCopliot(self)
#      87 file.close()
#      88 self.start += 1
# ---> 89 self.QueryCopliot()
#
# Cell In[2], line 89, in Copliot.QueryCopliot(self)
#      87 file.close()
#      88 self.start += 1
# ---> 89 self.QueryCopliot()
#
#     [... skipping similar frames: Copliot.QueryCopliot at line 89 (57 times)]
#
# Cell In[2], line 89, in Copliot.QueryCopliot(self)
#      87 file.close()
#      88 self.start += 1
# ---> 89 self.QueryCopliot()
#
# Cell In[2], line 80, in Copliot.QueryCopliot(self)
#      78 response_shadow_dom2 = dom1.find_element(by=By.CSS_SELECTOR, value="#cib-conversation-main").shadow_root
#      79 response_shadow_dom3 = response_shadow_dom2.find_element(by=By.CSS_SELECTOR, value="cib-chat-turn[serp-slot='none']").shadow_root
# ---> 80 response_shadow_dom4 = response_shadow_dom3.find_element(by=By.CSS_SELECTOR, value=".response-message-group").shadow_root
#      81 response_shadow_dom5 = response_shadow_dom4.find_element(by=By.CSS_SELECTOR, value="cib-message:nth-child(2)").shadow_root
#      82 response = response_shadow_dom5.find_element(by=By.CSS_SELECTOR, value="div[class='content']")
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\shadowroot.py:53, in ShadowRoot.find_element(self, by, value)
#      50     by = By.CSS_SELECTOR
#      51     value = f'[name="{value}"]'
# ---> 53 return self._execute(Command.FIND_ELEMENT_FROM_SHADOW_ROOT, {"using": by, "value": value})["value"]
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\shadowroot.py:82, in ShadowRoot._execute(self, command, params)
#      80     params = {}
#      81 params["shadowId"] = self._id
# ---> 82 return self.session.execute(command, params)
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     345 response = self.command_executor.execute(driver_command, params)
#     346 if response:
# --> 347     self.error_handler.check_response(response)
#     348     response["value"] = self._unwrap_value(response.get("value", None))
#     349     return response
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":".response-message-group"}
#   (Session info: chrome=122.0.6261.131); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF62BB8AD22+56930]
# 	(No symbol) [0x00007FF62BAFF622]
# 	(No symbol) [0x00007FF62B9B42E5]
# 	(No symbol) [0x00007FF62B9F98ED]
# 	(No symbol) [0x00007FF62B9F9A6C]
# 	(No symbol) [0x00007FF62B9EF17C]
# 	(No symbol) [0x00007FF62BA1BCDF]
# 	(No symbol) [0x00007FF62B9EF09A]
# 	(No symbol) [0x00007FF62BA1BEB0]
# 	(No symbol) [0x00007FF62BA381E2]
# 	(No symbol) [0x00007FF62BA1BA43]
# 	(No symbol) [0x00007FF62B9ED438]
# 	(No symbol) [0x00007FF62B9EE4D1]
# 	GetHandleVerifier [0x00007FF62BF06AAD+3709933]
# 	GetHandleVerifier [0x00007FF62BF5FFED+4075821]
# 	GetHandleVerifier [0x00007FF62BF5817F+4043455]
# 	GetHandleVerifier [0x00007FF62BC29756+706710]
# 	(No symbol) [0x00007FF62BB0B8FF]
# 	(No symbol) [0x00007FF62BB06AE4]
# 	(No symbol) [0x00007FF62BB06C3C]
# 	(No symbol) [0x00007FF62BAF68F4]
# 	BaseThreadInitThunk [0x00007FFF175A257D+29]
# 	RtlUserThreadStart [0x00007FFF1924AA58+40]
